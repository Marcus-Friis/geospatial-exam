# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
plt.xkcd()
import seaborn as sns
import contextily as cx
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed

# %% [markdown]
# ### Bikes
# [Get data here](https://www.opendata.dk/city-of-copenhagen/cykelparkeringstaelling#resource-cykelparkeringstaellinger.csv)

# %%
bikes = gpd.read_file('cykeltaellinger_2017.geojson')

# %%
bikes.head()
# Out:
#                                      id  id_1  \
# 0  ce271ca9-90a8-4906-89f8-e00c3a82e5de     1
# 1  00d5a80d-86db-445a-8477-224156bb2d5e     2
# 2  1fe7e8f5-5973-42fc-90c8-b427226e8acd     3
# 3  09dee499-0f6a-4689-b656-68b73dc85092     4
# 4  6fa55861-d68b-4edd-a5a5-f528043b7c1d     5
#
#                         taelleomra  pladser  cykelpaapl  cykeludenf  \
# 0  taelleomraader_cykelparkering.1        0           0           1
# 1  taelleomraader_cykelparkering.1        0           0           1
# 2  taelleomraader_cykelparkering.1        0           0           1
# 3  taelleomraader_cykelparkering.1        0           0           1
# 4  taelleomraader_cykelparkering.1        0           0           1
#
#    ladcykler          oprettet         redigeret   latitude  ...  cyk_diff  \
# 0          0  05.07.2017 08:52  05.07.2017 08:52  55.678744  ...         1
# 1          0  05.07.2017 08:52  05.07.2017 08:52  55.678699  ...         1
# ...

# %%
f, ax = plt.subplots(figsize=(12, 12))

basemap = cx.providers.CartoDB.DarkMatterNoLabels
bikes.plot(ax=ax, alpha=.3, markersize=2)
cx.add_basemap(ax=ax, crs=bikes.crs, source=basemap)
ax.set_axis_off()

# %% [markdown]
# ### Individual Facebook users
# [Get data here](https://dataforgood.facebook.com/dfg/tools/high-resolution-population-density-maps)

# %%
fb_df = pd.read_csv('dnk_general_2020.csv')

# %%
fb = gpd.GeoDataFrame(fb_df, geometry=gpd.points_from_xy(fb_df.longitude, fb_df.latitude))

# %%
f, ax = plt.subplots(figsize=(12,12))

fb.sample(1000000).plot(ax=ax, alpha=.2, markersize=2)
# Out:
# <AxesSubplot:>
