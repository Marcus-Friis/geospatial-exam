# %% [markdown]
# # Hygge-route planner

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import contextily as cx
import osmnx as ox
import networkx as nx

import matplotlib.pyplot as plt
import matplotlib.colors
import seaborn as sns

from collections import Counter
from random import choice
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed

# %% [markdown]
# ## Load data
# This data is exported by the `birds.ipynb` notebook. Birds are attributed to an edge if a 50m buffer around the bird intersects with a given street. Check out the notebook for more details.

# %%
edges = gpd.read_file('../data/edges_birds.json')
edges = edges.set_crs('EPSG:25832', allow_override=True)
edges.set_index(edges.id.apply(lambda x: x[1:-1].split(',')))
# Out:
#                                                             id access  \
# id
# [118725,  298795432,  0]                (118725, 298795432, 0)   None
# [118725,  6357644306,  0]              (118725, 6357644306, 0)   None
# [298795432,  298795496,  0]          (298795432, 298795496, 0)   None
# [6357644306,  2378383724,  0]      (6357644306, 2378383724, 0)   None
# [6357644306,  6357644350,  0]      (6357644306, 6357644350, 0)   None
# ...                                                        ...    ...
# [11808938472,  11808938473,  0]  (11808938472, 11808938473, 0)   None
# [11808938474,  11808938475,  0]  (11808938474, 11808938475, 0)   None
# [11808951459,  11808951460,  0]  (11808951459, 11808951460, 0)   None
# [11822755107,  11822755109,  0]  (11822755107, 11822755109, 0)   None
# [11822755110,  11822755108,  0]  (11822755110, 11822755108, 0)   None
#
#                                  bird_counts  birds_per_m junction   length  \
# id
# [118725,  298795432,  0]                 8.0     0.070877     None  112.872
# [118725,  6357644306,  0]                3.0     0.074080     None   40.497
# [298795432,  298795496,  0]              7.0     0.077950     None   89.801
# [6357644306,  2378383724,  0]            2.0     0.091199     None   21.930
# [6357644306,  6357644350,  0]            1.0     0.043373     None   23.056
# ...                                      ...          ...      ...      ...
# [11808938472,  11808938473,  0]          0.0     0.000000     None   13.119
# [11808938474,  11808938475,  0]          0.0     0.000000     None   10.142
# [11808951459,  11808951460,  0]          5.0     0.221582     None   22.565
# [11822755107,  11822755109,  0]          0.0     0.000000     None   42.758
# [11822755110,  11822755108,  0]          0.0     0.000000     None   15.667
#
#                                  oneway  \
# id
# [118725,  298795432,  0]           True
# [118725,  6357644306,  0]          True
# [298795432,  298795496,  0]        True
# [6357644306,  2378383724,  0]      True
# [6357644306,  6357644350,  0]      True
# ...                                 ...
# [11808938472,  11808938473,  0]   False
# [11808938474,  11808938475,  0]   False
# [11808951459,  11808951460,  0]   False
# [11822755107,  11822755109,  0]   False
# [11822755110,  11822755108,  0]   False
#
#                                                                           geometry
# id
# [118725,  298795432,  0]         LINESTRING (724025.025 6175551.339, 724031.889...
# [118725,  6357644306,  0]        LINESTRING (724025.025 6175551.339, 724051.956...
# [298795432,  298795496,  0]      LINESTRING (724075.369 6175450.104, 724076.732...
# [6357644306,  2378383724,  0]    LINESTRING (724059.919 6175572.112, 724075.704...
# [6357644306,  6357644350,  0]    LINESTRING (724059.919 6175572.112, 724081.508...
# ...                                                                            ...
# [11808938472,  11808938473,  0]  LINESTRING (722920.161 6172629.725, 722915.850...
# [11808938474,  11808938475,  0]  LINESTRING (722930.119 6172636.344, 722927.113...
# [11808951459,  11808951460,  0]  LINESTRING (722651.508 6180338.032, 722673.654...
# [11822755107,  11822755109,  0]  LINESTRING (727855.965 6174998.803, 727817.517...
# [11822755110,  11822755108,  0]  LINESTRING (727852.435 6175012.680, 727866.614...
#
# [62468 rows x 8 columns]

# %%
edges.head()
# Out:
#                             id access  bird_counts  birds_per_m junction  \
# 0       (118725, 298795432, 0)   None          8.0     0.070877     None
# 1      (118725, 6357644306, 0)   None          3.0     0.074080     None
# 2    (298795432, 298795496, 0)   None          7.0     0.077950     None
# 3  (6357644306, 2378383724, 0)   None          2.0     0.091199     None
# 4  (6357644306, 6357644350, 0)   None          1.0     0.043373     None
#
#     length  oneway                                           geometry
# 0  112.872    True  LINESTRING (724025.025 6175551.339, 724031.889...
# 1   40.497    True  LINESTRING (724025.025 6175551.339, 724051.956...
# 2   89.801    True  LINESTRING (724075.369 6175450.104, 724076.732...
# 3   21.930    True  LINESTRING (724059.919 6175572.112, 724075.704...
# 4   23.056    True  LINESTRING (724059.919 6175572.112, 724081.508...

# %%
nodes = gpd.read_file('../data/nodes.json').to_crs('EPSG:25832')
nodes = nodes.set_index('id')

# %%
nodes.head()
# Out:
#                 highway  street_count          x          y  \
# id
# 118725             None             3  12.562906  55.673985
# 118732  traffic_signals             4  12.561510  55.663099
# 118735             None             4  12.571933  55.668238
# 118738             None             3  12.561835  55.662837
# 118744             None             4  12.560034  55.661718
#
#                               geometry
# id
# 118725  POINT (724025.025 6175551.339)
# 118732  POINT (723999.539 6174336.199)
# 118735  POINT (724625.288 6174941.454)
# 118738  POINT (724021.470 6174308.056)
# 118744  POINT (723914.631 6174177.779)

# %% [markdown]
# ## Find best path minimizing distance and maximizing birds

# %% [markdown]
# ### Weighted sum of features
# One approach to create a routing algorithm that maximizes "hygge" is to weight each feature, and find the shortest path on this new composite feature. We use minmax scaling to get our features down into a comparable range
# $$
# x_{scaled} = \frac{x-x_{min}}{x_{max}-x_{min}}
# $$
# For the birds, we use $1-x_{scaled}$ as the feature, such that we can minimize the feature to maximize bird sightings

# %%
edges['w1'] = (edges['length'] - edges['length'].min()) / (edges['length'].max() - edges['length'].min())
edges['w2'] = 1 - ((edges['bird_counts'] - edges['bird_counts'].min()) / (edges['bird_counts'].max() - edges['bird_counts'].min()))

# %% [markdown]
# We can now create a "hygge" score as a weighted sum of the relevant features. The specific weights are parameters that need to be tuned for optimal routing.

# %%
edges['w'] = 0.9 * edges['w1'] + 0.1 * edges['w2']

# %% [markdown]
# We create a graph with the new hygge score on each edge.

# %%
G = ox.graph_from_gdfs(nodes, edges)
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/utils_graph.py:155: UserWarning: discarding the gdf_nodes geometry column, though its values differ from the coordinates in the x and y columns
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 G = ox.graph_from_gdfs(nodes, edges)
#
# File /opt/conda/lib/python3.9/site-packages/osmnx/utils_graph.py:169, in graph_from_gdfs(gdf_nodes, gdf_edges, graph_attrs)
#     166 # add edges and their attributes to graph, but filter out null attribute
#     167 # values so that edges only get attributes with non-null values
#     168 attr_names = gdf_edges.columns.to_list()
# --> 169 for (u, v, k), attr_vals in zip(gdf_edges.index, gdf_edges.values):
#     170     data_all = zip(attr_names, attr_vals)
#     171     data = {name: val for name, val in data_all if isinstance(val, list) or pd.notnull(val)}
#
# TypeError: cannot unpack non-iterable int object

# %% [markdown]
# This new hygge score is designed to be minimized. By using traditional shortest path algorithms, we can find the path that minimizes the hygge score, which in turn leads to minimizing path length and maximizing bird sightings.

# %% [markdown]
# ### Multiobjective shortest path - MOSP
